# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
import pandas as pd

# Load the dataset from a CSV file
df = pd.read_csv('./data/household_power_consumption_cleaned.csv', parse_dates=['datetime'])

# Set datetime as the index for time-series operations
df.set_index('datetime', inplace=True)

# Applying rolling window with different window sizes for better analysis
window_sizes = [3, 7, 14, 30, 60, 200]  # Short-term, medium-term, long-term trends

for window in window_sizes:
    df[f'Global_active_power_MA_{window}'] = df['Global_active_power'].rolling(window=window).mean()
    df[f'Global_reactive_power_MA_{window}'] = df['Global_reactive_power'].rolling(window=window).mean()
    df[f'Voltage_MA_{window}'] = df['Voltage'].rolling(window=window).mean()

# Display the first few rows to verify the calculations
print(df.head())
# Out:
#                      Global_active_power  Global_reactive_power  Voltage  \
# datetime
# 2006-12-16 17:24:00                4.216                  0.418   234.84
# 2006-12-16 17:25:00                5.360                  0.436   233.63
# 2006-12-16 17:26:00                5.374                  0.498   233.29
# 2006-12-16 17:27:00                5.388                  0.502   233.74
# 2006-12-16 17:28:00                3.666                  0.528   235.68
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# datetime
# 2006-12-16 17:24:00              18.4             0.0             1.0
# 2006-12-16 17:25:00              23.0             0.0             1.0
# 2006-12-16 17:26:00              23.0             0.0             2.0
# 2006-12-16 17:27:00              23.0             0.0             1.0
# 2006-12-16 17:28:00              15.8             0.0             1.0
#
#                      Sub_metering_3  Global_active_power_MA_3  \
# datetime
# 2006-12-16 17:24:00            17.0                       NaN
# 2006-12-16 17:25:00            16.0                       NaN
# 2006-12-16 17:26:00            17.0                  4.983333
# 2006-12-16 17:27:00            17.0                  5.374000
# 2006-12-16 17:28:00            17.0                  4.809333
#
#                      Global_reactive_power_MA_3  Voltage_MA_3  ...  \
# datetime                                                       ...
# 2006-12-16 17:24:00                         NaN           NaN  ...
# 2006-12-16 17:25:00                         NaN           NaN  ...
# 2006-12-16 17:26:00                    0.450667    233.920000  ...
# 2006-12-16 17:27:00                    0.478667    233.553333  ...
# 2006-12-16 17:28:00                    0.509333    234.236667  ...
#
#                      Voltage_MA_14  Global_active_power_MA_30  \
# datetime
# 2006-12-16 17:24:00            NaN                        NaN
# 2006-12-16 17:25:00            NaN                        NaN
# 2006-12-16 17:26:00            NaN                        NaN
# 2006-12-16 17:27:00            NaN                        NaN
# 2006-12-16 17:28:00            NaN                        NaN
#
#                      Global_reactive_power_MA_30  Voltage_MA_30  \
# datetime
# 2006-12-16 17:24:00                          NaN            NaN
# 2006-12-16 17:25:00                          NaN            NaN
# 2006-12-16 17:26:00                          NaN            NaN
# 2006-12-16 17:27:00                          NaN            NaN
# 2006-12-16 17:28:00                          NaN            NaN
#
#                      Global_active_power_MA_60  Global_reactive_power_MA_60  \
# datetime
# 2006-12-16 17:24:00                        NaN                          NaN
# 2006-12-16 17:25:00                        NaN                          NaN
# 2006-12-16 17:26:00                        NaN                          NaN
# 2006-12-16 17:27:00                        NaN                          NaN
# 2006-12-16 17:28:00                        NaN                          NaN
#
#                      Voltage_MA_60  Global_active_power_MA_200  \
# datetime
# 2006-12-16 17:24:00            NaN                         NaN
# 2006-12-16 17:25:00            NaN                         NaN
# 2006-12-16 17:26:00            NaN                         NaN
# 2006-12-16 17:27:00            NaN                         NaN
# 2006-12-16 17:28:00            NaN                         NaN
#
#                      Global_reactive_power_MA_200  Voltage_MA_200
# datetime
# 2006-12-16 17:24:00                           NaN             NaN
# 2006-12-16 17:25:00                           NaN             NaN
# 2006-12-16 17:26:00                           NaN             NaN
# 2006-12-16 17:27:00                           NaN             NaN
# 2006-12-16 17:28:00                           NaN             NaN
#
# [5 rows x 25 columns]

# %%
df.dropna(inplace=True)

# %%
df.to_csv('./data/power_consumption_with_moving_averages.csv')

# %%
df.head()
# Out:
#                      Global_active_power  Global_reactive_power  Voltage  \
# datetime
# 2006-12-16 20:43:00                3.372                  0.048   235.05
# 2006-12-16 20:44:00                3.366                  0.048   234.96
# 2006-12-16 20:45:00                3.386                  0.050   235.77
# 2006-12-16 20:46:00                3.496                  0.146   236.76
# 2006-12-16 20:47:00                3.426                  0.146   234.59
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# datetime
# 2006-12-16 20:43:00              14.2             0.0             0.0
# 2006-12-16 20:44:00              14.2             0.0             0.0
# 2006-12-16 20:45:00              14.2             0.0             0.0
# 2006-12-16 20:46:00              14.8             0.0             0.0
# 2006-12-16 20:47:00              14.6             0.0             0.0
#
#                      Sub_metering_3  Global_active_power_MA_3  \
# datetime
# 2006-12-16 20:43:00            17.0                  3.334000
# 2006-12-16 20:44:00            17.0                  3.371333
# 2006-12-16 20:45:00            17.0                  3.374667
# 2006-12-16 20:46:00            17.0                  3.416000
# 2006-12-16 20:47:00            17.0                  3.436000
#
#                      Global_reactive_power_MA_3  Voltage_MA_3  ...  \
# datetime                                                       ...
# 2006-12-16 20:43:00                    0.057333    234.703333  ...
# 2006-12-16 20:44:00                    0.048667    234.880000  ...
# 2006-12-16 20:45:00                    0.048667    235.260000  ...
# 2006-12-16 20:46:00                    0.081333    235.830000  ...
# 2006-12-16 20:47:00                    0.114000    235.706667  ...
#
#                      Voltage_MA_14  Global_active_power_MA_30  \
# datetime
# 2006-12-16 20:43:00     233.577857                   3.273467
# 2006-12-16 20:44:00     233.607857                   3.272733
# 2006-12-16 20:45:00     233.691429                   3.273267
# 2006-12-16 20:46:00     233.905000                   3.278733
# 2006-12-16 20:47:00     233.982857                   3.282600
#
#                      Global_reactive_power_MA_30  Voltage_MA_30  \
# datetime
# 2006-12-16 20:43:00                     0.053733     233.428000
# 2006-12-16 20:44:00                     0.050667     233.484667
# 2006-12-16 20:45:00                     0.049467     233.547000
# 2006-12-16 20:46:00                     0.054333     233.649667
# 2006-12-16 20:47:00                     0.059200     233.708333
#
#                      Global_active_power_MA_60  Global_reactive_power_MA_60  \
# datetime
# 2006-12-16 20:43:00                   3.288167                     0.075200
# 2006-12-16 20:44:00                   3.288133                     0.073433
# 2006-12-16 20:45:00                   3.288733                     0.071733
# 2006-12-16 20:46:00                   3.291133                     0.071633
# 2006-12-16 20:47:00                   3.292167                     0.071500
#
#                      Voltage_MA_60  Global_active_power_MA_200  \
# datetime
# 2006-12-16 20:43:00     233.121833                     3.59198
# 2006-12-16 20:44:00     233.168833                     3.58773
# 2006-12-16 20:45:00     233.238833                     3.57786
# 2006-12-16 20:46:00     233.323833                     3.56847
# 2006-12-16 20:47:00     233.363333                     3.55866
#
#                      Global_reactive_power_MA_200  Voltage_MA_200
# datetime
# 2006-12-16 20:43:00                       0.10403       233.91385
# 2006-12-16 20:44:00                       0.10218       233.91445
# 2006-12-16 20:45:00                       0.10025       233.92515
# 2006-12-16 20:46:00                       0.09849       233.94250
# 2006-12-16 20:47:00                       0.09671       233.94675
#
# [5 rows x 25 columns]
